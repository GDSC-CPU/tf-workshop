# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import pandas as pd

from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# We are going to load a CSV file using [pandas](https://pandas.pydata.org/).  The CSV file contains
# two examination scores, with 100 training samples in all.  Each is labelled as:
# - $1$ for **ADMITTED**
# - $0$ for **NOT ADMITTED**
#
# If you want to open the CSV file in your favorite spreadsheet, the link is [here](https://raw.githubusercontent.com/psse-cpu/ml-workshop/main/notebooks/playgrounds/admission-results.csv).

# %%
df = pd.read_csv('https://raw.githubusercontent.com/psse-cpu/ml-workshop/main/notebooks/playgrounds/admission-results.csv')
df
# Out:
#        Exam 1     Exam 2  Admitted
# 0   34.623660  78.024693         0
# 1   30.286711  43.894998         0
# 2   35.847409  72.902198         0
# 3   60.182599  86.308552         1
# 4   79.032736  75.344376         1
# ..        ...        ...       ...
# 95  83.489163  48.380286         1
# 96  42.261701  87.103851         1
# 97  99.315009  68.775409         1
# 98  55.340018  64.931938         1
# 99  74.775893  89.529813         1
#
# [100 rows x 3 columns]

# %% [markdown]
# Let's see the first 10 of those who are admitted, and convert to NumPy ASAP.  Let's not be
# overly friendly with this stranger library `pandas` for now 🐼.

# %%
admitted = df.query('Admitted == 1').to_numpy()
admitted[0:10]
# Out:
# array([[60.18259939, 86.3085521 ,  1.        ],
#        [79.03273605, 75.34437644,  1.        ],
#        [61.10666454, 96.51142588,  1.        ],
#        [75.02474557, 46.55401354,  1.        ],
#        [76.0987867 , 87.42056972,  1.        ],
#        [84.43281996, 43.53339331,  1.        ],
#        [82.30705337, 76.4819633 ,  1.        ],
#        [69.36458876, 97.71869196,  1.        ],
#        [53.97105215, 89.20735014,  1.        ],
#        [69.07014406, 52.74046973,  1.        ]])

# %% [markdown]
# Let's count how many were admitted.  Just see the matrix size _"na lang"_.

# %%
admitted.shape
# Out:
# (60, 3)

# %% [markdown]
# Let's get those who were not admitted, the last 10 this time.

# %%
not_admitted = df.query('Admitted == 0').to_numpy()
not_admitted[-11:-1]
# Out:
# array([[56.2538175 , 39.26147251,  0.        ],
#        [30.05882245, 49.59297387,  0.        ],
#        [44.66826172, 66.45008615,  0.        ],
#        [66.56089447, 41.09209808,  0.        ],
#        [49.07256322, 51.88321182,  0.        ],
#        [32.72283304, 43.30717306,  0.        ],
#        [60.45555629, 42.50840944,  0.        ],
#        [82.22666158, 42.71987854,  0.        ],
#        [42.07545454, 78.844786  ,  0.        ],
#        [52.34800399, 60.76950526,  0.        ]])

# %% [markdown]
# Should be a $40x3$ matrix right?

# %%
not_admitted.shape
# Out:
# (40, 3)

# %% [markdown]
# Let's plot to make sure that the boundary is linear.  As seen in the slides, some datasets have other shapes like polynomial, circle, strange curves, etc.
#
# What's nice with classification problems is that we can use two variables:
# - $x_1$ on the X-axis
# - $x_2$ on the Y-axis
# - and use a different color or symbol depending on $y$ is $1$ or $0$ 😂

# %%
plt.rcParams["figure.figsize"] = [10, 8] # bigger plot

plt.plot(admitted[:, [0]], admitted[:, [1]], 'go', markersize=7, label="Admitted")
plt.plot(not_admitted[:, [0]], not_admitted[:, [1]], 'rx', markersize=7, label="Not admitted")
plt.title('Admission Scatter Plot')
plt.xlabel('Exam 1 Score')
plt.ylabel('Exam 2 Score')
plt.legend()

# %% [markdown]
# Yup, a straight line would cause a
# - few red crosses to spill over the right side of the boundary
# - few green dots to spill over the left side
#
# but overall it should be an okay-ish 👌 approximation right?

# %% [markdown]
# We only needed the `admitted` and `not_admitted` variables for graphing.  For training our model, we'll still use `X` and `y`.  I'm in a good mood 🕺🕺, so I'll do it for you.
#
# $X$ should be a $100x2$ matrix.

# %%
X = df[['Exam 1', 'Exam 2']].to_numpy()
X.shape, X[0:10]
# Out:
# ((100, 2),
#  array([[34.62365962, 78.02469282],
#         [30.28671077, 43.89499752],
#         [35.84740877, 72.90219803],
#         [60.18259939, 86.3085521 ],
#         [79.03273605, 75.34437644],
#         [45.08327748, 56.31637178],
#         [61.10666454, 96.51142588],
#         [75.02474557, 46.55401354],
#         [76.0987867 , 87.42056972],
#         [84.43281996, 43.53339331]]))

# %% [markdown]
# $y$ should be a $100x1$ vector.

# %%
y = df[['Admitted']].to_numpy()
y.shape, y[0: 10]
# Out:
# ((100, 1),
#  array([[0],
#         [0],
#         [0],
#         [1],
#         [1],
#         [0],
#         [1],
#         [1],
#         [1],
#         [1]]))

# %% [markdown]
# And we say goodbye to 🐼 Pandas. Remember to **feature scale**.
#
# # YOUR TURN

# %%
# SCALE X HERE
scaler = MinMaxScaler()

X_norm = scaler.fit_transform(X)
X_norm[0: 5]
# Out:
# array([[0.06542784, 0.69465488],
#        [0.00326632, 0.19470455],
#        [0.08296784, 0.61961779],
#        [0.43176427, 0.81600135],
#        [0.7019434 , 0.65539214]])

# %%
# BUILD AND TRAIN YOUR CLASSIFIER HERE

model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(units=1, input_shape=[2], activation='sigmoid')
])
model.compile(
    loss=tf.keras.losses.BinaryCrossentropy(),
    optimizer=tf.keras.optimizers.SGD(learning_rate=0.1),
    metrics=['accuracy']
)

history = model.fit(X_norm, y, epochs=300)
# Out:
# Epoch 1/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.6686 - accuracy: 0.5900
# Epoch 2/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.6611 - accuracy: 0.6400
# Epoch 3/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.6543 - accuracy: 0.6400
# Epoch 4/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.6453 - accuracy: 0.6800
# Epoch 5/300
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6395 - accuracy: 0.6700
# Epoch 6/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.6353 - accuracy: 0.6800
# Epoch 7/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6334 - accuracy: 0.6800
# Epoch 8/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.6304 - accuracy: 0.7000
# Epoch 9/300
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6272 - accuracy: 0.7000
# Epoch 10/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.6242 - accuracy: 0.7000
# Epoch 11/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.6212 - accuracy: 0.7100
# Epoch 12/300
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6183 - accuracy: 0.7200
# Epoch 13/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6154 - accuracy: 0.7200
# Epoch 14/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.6125 - accuracy: 0.7000
# Epoch 15/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6112 - accuracy: 0.7200
# Epoch 16/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.6077 - accuracy: 0.7200
# Epoch 17/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.6062 - accuracy: 0.7200
# Epoch 18/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.6039 - accuracy: 0.7200
# Epoch 19/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.6011 - accuracy: 0.7300
# Epoch 20/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5993 - accuracy: 0.7200
# Epoch 21/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5975 - accuracy: 0.7300
# Epoch 22/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5972 - accuracy: 0.7200
# Epoch 23/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5929 - accuracy: 0.7200
# Epoch 24/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5910 - accuracy: 0.7200
# Epoch 25/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5890 - accuracy: 0.7200
# Epoch 26/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5873 - accuracy: 0.7200
# Epoch 27/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5844 - accuracy: 0.7300
# Epoch 28/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5818 - accuracy: 0.7300
# Epoch 29/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5800 - accuracy: 0.7300
# Epoch 30/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5785 - accuracy: 0.7300
# Epoch 31/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5762 - accuracy: 0.7300
# Epoch 32/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5745 - accuracy: 0.7300
# Epoch 33/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5732 - accuracy: 0.7300
# Epoch 34/300
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5714 - accuracy: 0.7200
# Epoch 35/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5701 - accuracy: 0.7200
# Epoch 36/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5680 - accuracy: 0.7200
# Epoch 37/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5658 - accuracy: 0.7300
# Epoch 38/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5648 - accuracy: 0.7100
# Epoch 39/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5623 - accuracy: 0.7200
# Epoch 40/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5612 - accuracy: 0.7200
# Epoch 41/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5589 - accuracy: 0.7300
# Epoch 42/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5570 - accuracy: 0.7400
# Epoch 43/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5543 - accuracy: 0.7300
# Epoch 44/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5528 - accuracy: 0.7300
# Epoch 45/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5504 - accuracy: 0.7400
# Epoch 46/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5485 - accuracy: 0.7400
# Epoch 47/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5468 - accuracy: 0.7400
# Epoch 48/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5459 - accuracy: 0.7400
# Epoch 49/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5440 - accuracy: 0.7400
# Epoch 50/300
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5431 - accuracy: 0.7400
# Epoch 51/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5405 - accuracy: 0.7400
# Epoch 52/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5393 - accuracy: 0.7400
# Epoch 53/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5375 - accuracy: 0.7500
# Epoch 54/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5371 - accuracy: 0.7400
# Epoch 55/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5349 - accuracy: 0.7400
# Epoch 56/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5330 - accuracy: 0.7600
# Epoch 57/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5315 - accuracy: 0.7500
# Epoch 58/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5297 - accuracy: 0.7600
# Epoch 59/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5282 - accuracy: 0.7500
# Epoch 60/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5266 - accuracy: 0.7600
# Epoch 61/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5257 - accuracy: 0.8100
# Epoch 62/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5236 - accuracy: 0.8000
# Epoch 63/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5231 - accuracy: 0.8200
# Epoch 64/300
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5208 - accuracy: 0.8100
# Epoch 65/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5194 - accuracy: 0.8000
# Epoch 66/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5179 - accuracy: 0.8100
# Epoch 67/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5161 - accuracy: 0.8200
# Epoch 68/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5144 - accuracy: 0.8200
# Epoch 69/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5129 - accuracy: 0.8200
# Epoch 70/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5115 - accuracy: 0.8300
# Epoch 71/300
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5105 - accuracy: 0.8300
# Epoch 72/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5087 - accuracy: 0.8200
# Epoch 73/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5075 - accuracy: 0.8300
# Epoch 74/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5063 - accuracy: 0.8500
# Epoch 75/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5059 - accuracy: 0.8300
# Epoch 76/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5038 - accuracy: 0.8500
# Epoch 77/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5023 - accuracy: 0.8500
# Epoch 78/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5029 - accuracy: 0.8500
# Epoch 79/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5003 - accuracy: 0.8400
# Epoch 80/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4991 - accuracy: 0.8500
# Epoch 81/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4981 - accuracy: 0.8500
# Epoch 82/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4971 - accuracy: 0.8500
# Epoch 83/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4958 - accuracy: 0.8600
# Epoch 84/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4937 - accuracy: 0.8500
# Epoch 85/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4927 - accuracy: 0.8500
# Epoch 86/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4922 - accuracy: 0.8700
# Epoch 87/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4911 - accuracy: 0.8600
# Epoch 88/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4892 - accuracy: 0.8700
# Epoch 89/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4876 - accuracy: 0.8600
# Epoch 90/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4862 - accuracy: 0.8700
# Epoch 91/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4858 - accuracy: 0.8800
# Epoch 92/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4839 - accuracy: 0.8800
# Epoch 93/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4820 - accuracy: 0.8600
# Epoch 94/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4808 - accuracy: 0.8700
# Epoch 95/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4797 - accuracy: 0.8800
# Epoch 96/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4786 - accuracy: 0.8800
# Epoch 97/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4774 - accuracy: 0.8600
# Epoch 98/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4760 - accuracy: 0.8600
# Epoch 99/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4749 - accuracy: 0.8500
# Epoch 100/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4741 - accuracy: 0.8400
# Epoch 101/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4728 - accuracy: 0.8300
# Epoch 102/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4723 - accuracy: 0.8100
# Epoch 103/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4709 - accuracy: 0.8300
# Epoch 104/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4705 - accuracy: 0.8100
# Epoch 105/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4687 - accuracy: 0.8200
# Epoch 106/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4681 - accuracy: 0.8100
# Epoch 107/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4671 - accuracy: 0.8200
# Epoch 108/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4659 - accuracy: 0.8200
# Epoch 109/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4654 - accuracy: 0.8100
# Epoch 110/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4639 - accuracy: 0.8200
# Epoch 111/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4624 - accuracy: 0.8200
# Epoch 112/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4618 - accuracy: 0.8200
# Epoch 113/300
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4599 - accuracy: 0.8500
# Epoch 114/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4586 - accuracy: 0.8500
# Epoch 115/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4576 - accuracy: 0.8600
# Epoch 116/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4566 - accuracy: 0.8500
# Epoch 117/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4559 - accuracy: 0.8600
# Epoch 118/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4555 - accuracy: 0.8800
# Epoch 119/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4541 - accuracy: 0.8800
# Epoch 120/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4531 - accuracy: 0.8700
# Epoch 121/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4520 - accuracy: 0.8800
# Epoch 122/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4512 - accuracy: 0.8700
# Epoch 123/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4504 - accuracy: 0.8800
# Epoch 124/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4498 - accuracy: 0.8800
# Epoch 125/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4484 - accuracy: 0.8700
# Epoch 126/300
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4475 - accuracy: 0.8800
# Epoch 127/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4465 - accuracy: 0.8700
# Epoch 128/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4456 - accuracy: 0.8500
# Epoch 129/300
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4450 - accuracy: 0.8400
# Epoch 130/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4438 - accuracy: 0.8500
# Epoch 131/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4430 - accuracy: 0.8400
# Epoch 132/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4417 - accuracy: 0.8500
# Epoch 133/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4406 - accuracy: 0.8800
# Epoch 134/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4400 - accuracy: 0.8600
# Epoch 135/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4391 - accuracy: 0.8500
# Epoch 136/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4382 - accuracy: 0.8600
# Epoch 137/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4373 - accuracy: 0.8700
# Epoch 138/300
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4365 - accuracy: 0.8600
# Epoch 139/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4357 - accuracy: 0.8900
# Epoch 140/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4350 - accuracy: 0.8800
# Epoch 141/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4339 - accuracy: 0.8800
# Epoch 142/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4333 - accuracy: 0.8500
# Epoch 143/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4324 - accuracy: 0.8700
# Epoch 144/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4316 - accuracy: 0.8600
# Epoch 145/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4307 - accuracy: 0.8700
# Epoch 146/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4301 - accuracy: 0.8600
# Epoch 147/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4297 - accuracy: 0.8500
# Epoch 148/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4290 - accuracy: 0.8500
# Epoch 149/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4287 - accuracy: 0.8400
# Epoch 150/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4278 - accuracy: 0.8400
# Epoch 151/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4267 - accuracy: 0.8500
# Epoch 152/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4259 - accuracy: 0.8500
# Epoch 153/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4251 - accuracy: 0.8500
# Epoch 154/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4243 - accuracy: 0.8500
# Epoch 155/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4233 - accuracy: 0.8500
# Epoch 156/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4226 - accuracy: 0.8500
# Epoch 157/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4218 - accuracy: 0.8800
# Epoch 158/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4209 - accuracy: 0.8900
# Epoch 159/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4202 - accuracy: 0.8900
# Epoch 160/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4194 - accuracy: 0.8800
# Epoch 161/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4189 - accuracy: 0.8800
# Epoch 162/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4185 - accuracy: 0.8700
# Epoch 163/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4175 - accuracy: 0.8700
# Epoch 164/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4166 - accuracy: 0.8800
# Epoch 165/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4165 - accuracy: 0.8900
# Epoch 166/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4155 - accuracy: 0.8900
# Epoch 167/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4149 - accuracy: 0.8700
# Epoch 168/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4137 - accuracy: 0.9000
# Epoch 169/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4133 - accuracy: 0.9100
# Epoch 170/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4129 - accuracy: 0.9100
# Epoch 171/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4119 - accuracy: 0.9100
# Epoch 172/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4114 - accuracy: 0.9100
# Epoch 173/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4108 - accuracy: 0.9100
# Epoch 174/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4097 - accuracy: 0.9100
# Epoch 175/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4092 - accuracy: 0.8900
# Epoch 176/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4086 - accuracy: 0.8800
# Epoch 177/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4084 - accuracy: 0.8600
# Epoch 178/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4074 - accuracy: 0.8900
# Epoch 179/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4067 - accuracy: 0.8800
# Epoch 180/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4063 - accuracy: 0.8900
# Epoch 181/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4051 - accuracy: 0.9100
# Epoch 182/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4046 - accuracy: 0.9000
# Epoch 183/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4040 - accuracy: 0.9100
# Epoch 184/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4037 - accuracy: 0.9100
# Epoch 185/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4031 - accuracy: 0.9100
# Epoch 186/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4023 - accuracy: 0.9200
# Epoch 187/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4016 - accuracy: 0.9200
# Epoch 188/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4010 - accuracy: 0.9100
# Epoch 189/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4004 - accuracy: 0.9200
# Epoch 190/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4002 - accuracy: 0.9200
# Epoch 191/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3993 - accuracy: 0.9100
# Epoch 192/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3986 - accuracy: 0.9100
# Epoch 193/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3982 - accuracy: 0.9100
# Epoch 194/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3976 - accuracy: 0.9100
# Epoch 195/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3967 - accuracy: 0.9200
# Epoch 196/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3963 - accuracy: 0.9100
# Epoch 197/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3957 - accuracy: 0.9100
# Epoch 198/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3957 - accuracy: 0.9200
# Epoch 199/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3945 - accuracy: 0.9100
# Epoch 200/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3943 - accuracy: 0.9100
# Epoch 201/300
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3936 - accuracy: 0.9200
# Epoch 202/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3931 - accuracy: 0.9200
# Epoch 203/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3925 - accuracy: 0.9200
# Epoch 204/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3923 - accuracy: 0.9200
# Epoch 205/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3915 - accuracy: 0.9200
# Epoch 206/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3908 - accuracy: 0.9200
# Epoch 207/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3901 - accuracy: 0.9200
# Epoch 208/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3895 - accuracy: 0.9200
# Epoch 209/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3886 - accuracy: 0.9100
# Epoch 210/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3882 - accuracy: 0.9100
# Epoch 211/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3874 - accuracy: 0.9100
# Epoch 212/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3869 - accuracy: 0.9200
# Epoch 213/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3865 - accuracy: 0.9200
# Epoch 214/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3861 - accuracy: 0.9100
# Epoch 215/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3855 - accuracy: 0.9100
# Epoch 216/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3852 - accuracy: 0.9100
# Epoch 217/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3844 - accuracy: 0.9100
# Epoch 218/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3839 - accuracy: 0.9200
# Epoch 219/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3835 - accuracy: 0.9100
# Epoch 220/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3829 - accuracy: 0.9100
# Epoch 221/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3822 - accuracy: 0.9200
# Epoch 222/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3817 - accuracy: 0.9200
# Epoch 223/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3814 - accuracy: 0.9100
# Epoch 224/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3809 - accuracy: 0.9100
# Epoch 225/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3808 - accuracy: 0.9100
# Epoch 226/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3801 - accuracy: 0.9200
# Epoch 227/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3795 - accuracy: 0.9100
# Epoch 228/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3792 - accuracy: 0.9100
# Epoch 229/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3787 - accuracy: 0.9100
# Epoch 230/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3781 - accuracy: 0.9200
# Epoch 231/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3773 - accuracy: 0.9200
# Epoch 232/300
# 4/4 [==============================] - 0s 1ms/step - loss: 0.3768 - accuracy: 0.9200
# Epoch 233/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3765 - accuracy: 0.9200
# Epoch 234/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3762 - accuracy: 0.9200
# Epoch 235/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3755 - accuracy: 0.9200
# Epoch 236/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3753 - accuracy: 0.9200
# Epoch 237/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3746 - accuracy: 0.9200
# Epoch 238/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3742 - accuracy: 0.9200
# Epoch 239/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3740 - accuracy: 0.9200
# Epoch 240/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3731 - accuracy: 0.9200
# Epoch 241/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3727 - accuracy: 0.9200
# Epoch 242/300
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3724 - accuracy: 0.9200
# Epoch 243/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3718 - accuracy: 0.9200
# Epoch 244/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3716 - accuracy: 0.9200
# Epoch 245/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3711 - accuracy: 0.9200
# Epoch 246/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3707 - accuracy: 0.9200
# Epoch 247/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3702 - accuracy: 0.9200
# Epoch 248/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3698 - accuracy: 0.9200
# Epoch 249/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3693 - accuracy: 0.9200
# Epoch 250/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3686 - accuracy: 0.9200
# Epoch 251/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3681 - accuracy: 0.9200
# Epoch 252/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3677 - accuracy: 0.9200
# Epoch 253/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3673 - accuracy: 0.9200
# Epoch 254/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3669 - accuracy: 0.9200
# Epoch 255/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3670 - accuracy: 0.9200
# Epoch 256/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3662 - accuracy: 0.9200
# Epoch 257/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3658 - accuracy: 0.9200
# Epoch 258/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3653 - accuracy: 0.9200
# Epoch 259/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3651 - accuracy: 0.9200
# Epoch 260/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3649 - accuracy: 0.9100
# Epoch 261/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3647 - accuracy: 0.9100
# Epoch 262/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3643 - accuracy: 0.9100
# Epoch 263/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3645 - accuracy: 0.9100
# Epoch 264/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3632 - accuracy: 0.9100
# Epoch 265/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3628 - accuracy: 0.9100
# Epoch 266/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3621 - accuracy: 0.9200
# Epoch 267/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3618 - accuracy: 0.9100
# Epoch 268/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3613 - accuracy: 0.9200
# Epoch 269/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3612 - accuracy: 0.9100
# Epoch 270/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3606 - accuracy: 0.9200
# Epoch 271/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3607 - accuracy: 0.9100
# Epoch 272/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3609 - accuracy: 0.9100
# Epoch 273/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3610 - accuracy: 0.9100
# Epoch 274/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3609 - accuracy: 0.9100
# Epoch 275/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3602 - accuracy: 0.9100
# Epoch 276/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3598 - accuracy: 0.9100
# Epoch 277/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3590 - accuracy: 0.9100
# Epoch 278/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3583 - accuracy: 0.9100
# Epoch 279/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3575 - accuracy: 0.9100
# Epoch 280/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3572 - accuracy: 0.9100
# Epoch 281/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3568 - accuracy: 0.9100
# Epoch 282/300
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3565 - accuracy: 0.9100
# Epoch 283/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3557 - accuracy: 0.9200
# Epoch 284/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3553 - accuracy: 0.9200
# Epoch 285/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3550 - accuracy: 0.9200
# Epoch 286/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3545 - accuracy: 0.9200
# Epoch 287/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3540 - accuracy: 0.9200
# Epoch 288/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3537 - accuracy: 0.9200
# Epoch 289/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3533 - accuracy: 0.9200
# Epoch 290/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3530 - accuracy: 0.9200
# Epoch 291/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3528 - accuracy: 0.9200
# Epoch 292/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3523 - accuracy: 0.9200
# Epoch 293/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3520 - accuracy: 0.9200
# Epoch 294/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3514 - accuracy: 0.9300
# Epoch 295/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3518 - accuracy: 0.9300
# Epoch 296/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3507 - accuracy: 0.9300
# Epoch 297/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3504 - accuracy: 0.9200
# Epoch 298/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3501 - accuracy: 0.9300
# Epoch 299/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3501 - accuracy: 0.9200
# Epoch 300/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3495 - accuracy: 0.9200

# %% [markdown]
# Create your predict function here.  It should output a 1 if the probability of **Admission** is 50% or more.

# %%
def normalize_and_predict(input):
    return model.predict(scaler.transform(input)) >= 0.5

# %%
applicant_scores = np.array([
    [100, 100], # wow perfect
    [30, 30],   # wow lowest in both
    [30, 60],   # lowest + kabit
    [70, 35],   # average score + quite low
    [50, 50],   # kabit?
    [65, 55],   # kabit++?
    [65, 65],   # labaw lang gamay sa kabit?
    [85, 80],   # below genius
])

"""
I got the following:
array([[ True],
       [False],
       [False],
       [False],
       [False],
       [False],
       [ True],
       [ True]])

Makes sense to me.
"""

normalize_and_predict(applicant_scores)
# Out:
# array([[ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True]])

# %% [markdown]
# Now we'll rerun the entire training set against our ML model.  Tensorflow can also calculate this _"accuracy"_ metric for us, but we'll learn this in the next lesson.
#
# I got a value of $92\%$ here, using:
# - learning rate $\alpha = 0.1$
# - epochs = 300
#
# It means 92% of its predictions match the original label $y$.

# %%
# no need to divide by `y.size * 100` since there are 100 training samples!
np.sum(normalize_and_predict(X) == y)
# Out:
# 89

# %% [markdown]
# Not bad.  It will make tons of wrong predictions at the boundary line since they're the _50-50_ types.
#
# Also, many tutorials [like this](https://www.johnwittenauer.net/machine-learning-exercises-in-python-part-3/)
# that write this classifier from scratch without Tensorflow get an accuracy of $89\%$.
#
# # 🤗

# %%
theta = np.vstack((model.weights[1].numpy(), model.weights[0].numpy()))
theta
# Out:
# array([[-7.572812],
#        [ 8.604296],
#        [ 8.149452]], dtype=float32)

# %%
plt.rcParams["figure.figsize"] = [10, 8] # bigger plot

duh_data = np.vstack((admitted, not_admitted))
duh_X_positive = scaler.transform(duh_data[0:60, 0:2])
duh_X_negative = scaler.transform(duh_data[60:, 0:2])

plt.plot(duh_X_positive[:, [0]], duh_X_positive[:, [1]], 'go', markersize=7, label="Admitted")
plt.plot(duh_X_negative[:, [0]], duh_X_negative[:, [1]], 'rx', markersize=7, label="Not admitted")

x1 = np.arange(0, 1, 0.1)
x2 = -(theta[0] + theta[1] * x1) / theta[2]

plt.title('Admission Scatter Plot (VALUES NORMALIZED from 0 to 1)')
plt.xlabel('Exam 1 Score')
plt.ylabel('Exam 2 Score')
plt.legend()

x1, x2

plt.plot(x1, x2)
plt.savefig('../workshop-templates.jpg')
